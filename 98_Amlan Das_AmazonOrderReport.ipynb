# %%
import pandas as pd

# %%
s = pd.read_csv('C:\\Users\\ASUS\\Downloads\\amazon_order_history.csv')

# %%
s
# Out:
#                order id                                              items  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...

# %%
#number of rows
len(s)
# Out:
# 30

# %%
#column names
s.columns
# Out:
# Index(['order id', 'items', 'to', 'date', 'total', 'shipping',
#        'shipping_refund', 'gift', 'VAT', 'refund', 'payments'],
#       dtype='object')

# %%
s.columns = ['OrderID', 'PurchasedItem', 'CustomerName', 'OrderDate', 'AmountPaid', 'ShippingCharges', 'ShippingChargesRefund', 'Gift', 'VAT', 'RefundAmount', 'ModeOfPayment']

# %%
s.columns
# Out:
# Index(['OrderID', 'PurchasedItem', 'CustomerName', 'OrderDate', 'AmountPaid',
#        'ShippingCharges', 'ShippingChargesRefund', 'Gift', 'VAT',
#        'RefundAmount', 'ModeOfPayment'],
#       dtype='object')

# %%
s.drop('Gift', axis = 1)
# Out:
#                 OrderID                                      PurchasedItem  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...

# %%
s[0 : 29]
# Out:
#                 OrderID                                      PurchasedItem  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...

# %%
s1 = s[0 : 29]

# %%
s1
# Out:
#                 OrderID                                      PurchasedItem  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...

# %%
s1["AmountPaid"] = s1["AmountPaid"].str.replace('Rs.', '').str.replace(',', '')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11768\1767178566.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   s1["AmountPaid"] = s1["AmountPaid"].str.replace('Rs.', '').str.replace(',', '')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11768\1767178566.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s1["AmountPaid"] = s1["AmountPaid"].str.replace('Rs.', '').str.replace(',', '')

# %%
s1["AmountPaid"].astype(float)
# Out:
# 0        0.00
# 1     1399.00
# 2     1395.00
# 3      385.00
# 4      385.00
# 5      264.00
# 6      719.00
# 7      849.00
# 8     1177.00
# 9      362.00
# 10       0.00
# 11     807.00
# 12     677.00
# 13     197.00
# 14     299.00
# 15     499.00
# 16     440.00
# 17     290.00
# 18     505.00
# 19     524.66
# 20    9499.00
# 21     699.00
# 22     789.00
# 23     344.00
# 24     999.00
# 25     999.00
# 26     231.00
# 27    1998.00
# 28     699.00
# Name: AmountPaid, dtype: float64

# %%
s1["AmountPaid"].sum()
# Out:
# '01399.001395.00385.00385.00264.00719.00849.001177.00362.000.00807.00677.00197.00299.00499.00440.00290.00505.00524.669499.00699.00789.00344.00999.00999.00231.001998.00699.00'

# %%
s1["AmountPaid"] = s1["AmountPaid"].astype(float)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11768\2367366541.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s1["AmountPaid"] = s1["AmountPaid"].astype(float)

# %%
s1["AmountPaid"].sum()
# Out:
# 27430.66

# %%
s1["AmountPaid"].mean()
# Out:
# 945.8848275862069

# %%
s1["AmountPaid"].median()
# Out:
# 524.66

# %%
s1["AmountPaid"].max()
# Out:
# 9499.0

# %%
s1["AmountPaid"].min()
# Out:
# 0.0

# %%
s1['ModeOfPayment'] = s1['ModeOfPayment'].str.replace('UNKNOWN;','ONLINE')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11768\2774521552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s1['ModeOfPayment'] = s1['ModeOfPayment'].str.replace('UNKNOWN;','ONLINE')

# %%
s1
# Out:
#                 OrderID                                      PurchasedItem  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...

# %%
s1['ShippingCharges'].describe()
# Out:
# count           29
# unique           6
# top       Rs. 0.00
# freq            13
# Name: ShippingCharges, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(s1)

# %%
sns.histplot(s1['ShippingCharges'], bins=20, kde=True)
# Out:
# <AxesSubplot: xlabel='ShippingCharges', ylabel='Count'>

# %%
sns.histplot(s1['AmountPaid'], bins=20, kde=True)
# Out:
# <AxesSubplot: xlabel='AmountPaid', ylabel='Count'>

# %%
sns.countplot(x='ModeOfPayment', data=s1)
# Out:
# <AxesSubplot: xlabel='ModeOfPayment', ylabel='count'>

# %%
sns.heatmap(s1.corr())
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11768\2260468006.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(s1.corr())
# <AxesSubplot: >

# %%
plt.figure(figsize = (23,7))
sns.boxplot(x = s1['AmountPaid'])
# Out:
# <AxesSubplot: xlabel='AmountPaid'>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
day = s1['OrderDate'].apply(lambda x : x.split('-')[2])
month = s1['OrderDate'].apply(lambda x : x.split('-')[1])
year = s1['OrderDate'].apply(lambda x : x.split('-')[0])

# %%
day
# Out:
# 0     28
# 1     20
# 2     20
# 3     18
# 4     15
# 5     23
# 6     23
# 7     23
# 8     25
# 9     24
# 10    12
# 11    21
# 12    11
# 13    10
# 14    10
# 15    04
# 16    26
# 17    16
# 18    01
# 19    24
# 20    17
# 21    17
# 22    12
# 23    03
# 24    30
# 25    23
# 26    23
# 27    20
# 28    16
# Name: OrderDate, dtype: object

# %%
month
# Out:
# 0     12
# 1     12
# 2     12
# 3     12
# 4     11
# 5     10
# 6     10
# 7     10
# 8     09
# 9     09
# 10    07
# 11    06
# 12    02
# 13    02
# 14    02
# 15    02
# 16    01
# 17    01
# 18    01
# 19    09
# 20    09
# 21    09
# 22    09
# 23    09
# 24    08
# 25    08
# 26    08
# 27    08
# 28    08
# Name: OrderDate, dtype: object

# %%
year
# Out:
# 0     2021
# 1     2021
# 2     2021
# 3     2021
# 4     2021
# 5     2021
# 6     2021
# 7     2021
# 8     2021
# 9     2021
# 10    2021
# 11    2021
# 12    2021
# 13    2021
# 14    2021
# 15    2021
# 16    2021
# 17    2021
# 18    2021
# 19    2021
# 20    2021
# 21    2021
# 22    2021
# 23    2021
# 24    2021
# 25    2021
# 26    2021
# 27    2021
# 28    2021
# Name: OrderDate, dtype: object

# %%
s1
# Out:
#                 OrderID                                      PurchasedItem  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...

# %%
s1.drop(['OrderDate'], axis=1, inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11768\3696682219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s1.drop(['OrderDate'], axis=1, inplace=True)

# %%
s1
# Out:
#                 OrderID                                      PurchasedItem  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...

# %%
s1 = pd.concat([s1,day,month,year], axis=1)

# %%
s1
# Out:
#                 OrderID                                      PurchasedItem  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...

# %%
columns = list(s1.columns)

# %%
columns = columns[:len(columns)-3]
columns
# Out:
# ['OrderID',
#  'PurchasedItem',
#  'CustomerName',
#  'AmountPaid',
#  'ShippingCharges',
#  'ShippingChargesRefund',
#  'Gift',
#  'VAT',
#  'RefundAmount',
#  'ModeOfPayment']

# %%
columns.extend(['day','month','year'])

# %%
columns
# Out:
# ['OrderID',
#  'PurchasedItem',
#  'CustomerName',
#  'AmountPaid',
#  'ShippingCharges',
#  'ShippingChargesRefund',
#  'Gift',
#  'VAT',
#  'RefundAmount',
#  'ModeOfPayment',
#  'day',
#  'month',
#  'year']

# %%
s1
# Out:
#                 OrderID                                      PurchasedItem  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...

# %%
s1.columns = columns

# %%
s1.columns
# Out:
# Index(['OrderID', 'PurchasedItem', 'CustomerName', 'AmountPaid',
#        'ShippingCharges', 'ShippingChargesRefund', 'Gift', 'VAT',
#        'RefundAmount', 'ModeOfPayment', 'day', 'month', 'year'],
#       dtype='object')

# %%
s1
# Out:
#                 OrderID                                      PurchasedItem  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...

# %%
categorical = list()
numeric = list()
for i in ['day','month','year']:
  if s1[i].nunique() < 10:
    categorical.append(i)
  else:
    numeric.append(i)

# %%
categorical
# Out:
# ['month', 'year']

# %%
numeric = numeric[len(numeric)-2:]

# %%
numeric
# Out:
# ['day']

# %%
s2 = pd.get_dummies(data=s1, columns=categorical)

# %%
s2
# Out:
#                 OrderID                                      PurchasedItem  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...

# %%
s2.columns
# Out:
# Index(['OrderID', 'PurchasedItem', 'CustomerName', 'AmountPaid',
#        'ShippingCharges', 'ShippingChargesRefund', 'Gift', 'VAT',
#        'RefundAmount', 'ModeOfPayment', 'day', 'month_01', 'month_02',
#        'month_06', 'month_07', 'month_08', 'month_09', 'month_10', 'month_11',
#        'month_12', 'year_2021'],
#       dtype='object')

# %%
s2
# Out:
#                 OrderID                                      PurchasedItem  \
# 0   407-0369441-4249130          Mobile Prepaid Recharge; Recharge Again;
# 1   407-6253025-7422747     Pashtush Womens Jamawar Shawl Parent (Ivory);
# 2   407-5263391-7393147  Women's Kashmiri Aari Embroidery Stole, Shawl,...
# 3   407-2457383-5169939                    Ruma T Capsule 30 (pack of 2);
# 4   408-5433055-7860369                    Ruma T Capsule 30 (pack of 2);
# 5   407-3674468-7653121  Best Choice Nutrition Pure Vitamin E Capsule F...
# 6   407-1271100-2197959  US Polo Association Men's Solid Regular Fit Co...
# 7   407-6978179-1480364  US Polo Association Men's Solid Regular Fit Co...
# 8   407-0413376-0533141  Ultimate Trends Digital Printed Floral Polyest...
# 9   402-1459255-5735505                       My Turn: The Autobiography;
# 10  404-1590621-8345930                          Prime by Tata Sky India;
# 11  407-0594766-3913103  Story@Home Cotton Face Towel 450 GSM (Set of 6...
# ...
